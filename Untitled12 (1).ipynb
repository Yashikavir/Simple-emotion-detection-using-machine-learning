# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.12.0

# %%
images = glob("desktop/train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %%
images = glob("desktop/train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("desktop/train/",
                                                   target_size = (img_size,img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)

datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("desktop/test/",
                                                   target_size = (img_size,img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(conv_1,64,(5,5))
    conv_3 = Convolution(conv_2,128,(3,3))

    flatten = Flatten()(conv_3)
    
    dense_1 = Dense_f(flatten,256)

    output  = Dense(7, activation="softmax")(dense_1)
    model  =  Model(inputs=[inputs],outputs = [output])
    
    model.compile(loss=['categorical_crossentropy'] , optimizer = 'adam' , metrics =["accuracy"])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  batch_normalization (BatchN  (None, 48, 48, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 32)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        51264
#
#  batch_normalization_1 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 24, 24, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 12, 12, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 1,309,063
# Trainable params: 1,308,103
# Non-trainable params: 960
# _________________________________________________________________

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("weights.weights.h5", monitor  ='val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
callbacks = [checkpoint]

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# Epoch 1/15
# 2024-04-17 17:35:46.009467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 448/448 [==============================] - ETA: 0s - loss: 1.0452 - accuracy: 0.6064
# Epoch 1: saving model to weights.weights.h5
# 448/448 [==============================] - 62s 139ms/step - loss: 1.0452 - accuracy: 0.6064 - val_loss: 1.1180 - val_accuracy: 0.5864
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0021 - accuracy: 0.6199
# Epoch 2: saving model to weights.weights.h5
# 448/448 [==============================] - 64s 143ms/step - loss: 1.0021 - accuracy: 0.6199 - val_loss: 1.2629 - val_accuracy: 0.5381
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9697 - accuracy: 0.6391
# Epoch 3: saving model to weights.weights.h5
# 448/448 [==============================] - 63s 141ms/step - loss: 0.9697 - accuracy: 0.6391 - val_loss: 1.1617 - val_accuracy: 0.5700
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9215 - accuracy: 0.6563
# Epoch 4: saving model to weights.weights.h5
# 448/448 [==============================] - 67s 150ms/step - loss: 0.9215 - accuracy: 0.6563 - val_loss: 1.2679 - val_accuracy: 0.5272
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8925 - accuracy: 0.6674
# Epoch 5: saving model to weights.weights.h5
# 448/448 [==============================] - 68s 151ms/step - loss: 0.8925 - accuracy: 0.6674 - val_loss: 1.0803 - val_accuracy: 0.6032
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8483 - accuracy: 0.6858
# Epoch 6: saving model to weights.weights.h5
# 448/448 [==============================] - 69s 154ms/step - loss: 0.8483 - accuracy: 0.6858 - val_loss: 1.0799 - val_accuracy: 0.6055
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8135 - accuracy: 0.6985
# Epoch 7: saving model to weights.weights.h5
# 448/448 [==============================] - 70s 156ms/step - loss: 0.8135 - accuracy: 0.6985 - val_loss: 1.1589 - val_accuracy: 0.5785
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7835 - accuracy: 0.7087
# Epoch 8: saving model to weights.weights.h5
# 448/448 [==============================] - 73s 162ms/step - loss: 0.7835 - accuracy: 0.7087 - val_loss: 1.1148 - val_accuracy: 0.5989
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7443 - accuracy: 0.7241
# Epoch 9: saving model to weights.weights.h5
# 448/448 [==============================] - 70s 155ms/step - loss: 0.7443 - accuracy: 0.7241 - val_loss: 1.1839 - val_accuracy: 0.5767
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7079 - accuracy: 0.7383
# Epoch 10: saving model to weights.weights.h5
# 448/448 [==============================] - 66s 147ms/step - loss: 0.7079 - accuracy: 0.7383 - val_loss: 1.1771 - val_accuracy: 0.5840
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6901 - accuracy: 0.7462
# Epoch 11: saving model to weights.weights.h5
# 448/448 [==============================] - 67s 150ms/step - loss: 0.6901 - accuracy: 0.7462 - val_loss: 1.1610 - val_accuracy: 0.6009
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6531 - accuracy: 0.7607
# Epoch 12: saving model to weights.weights.h5
# 448/448 [==============================] - 73s 163ms/step - loss: 0.6531 - accuracy: 0.7607 - val_loss: 1.2261 - val_accuracy: 0.5699
# Epoch 13/15
#  68/448 [===>..........................] - ETA: 52s - loss: 0.5895 - accuracy: 0.7884

# %%
model.evaluate(validation_generator)

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
model_json = model.to_json()
with open("model_a1.json","w") as json_file:
    json_file.write(model_json)
